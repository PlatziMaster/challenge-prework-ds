# %%
import pandas as bd

# %%
datos = bd.read_csv('INAH_detallado_2019.csv', encoding='latin-1')

# %%
datos
# Out:
#                Estado  Clave SIINAH   Siglas  \
# 0      Aguascalientes     2300100.0  M.- M.H
# 1      Aguascalientes     2300100.0  M.- M.H
# 2      Aguascalientes     2300100.0  M.- M.H
# 3      Aguascalientes     2300100.0  M.- M.H
# 4      Aguascalientes     2300100.0  M.- M.H
# ...               ...           ...      ...
# 42674       Zacatecas     3110022.0     Z.A.
# 42675       Zacatecas     3110022.0     Z.A.
# 42676       Zacatecas     3110022.0     Z.A.
# 42677       Zacatecas     3110022.0     Z.A.
# 42678       Zacatecas     3110022.0     Z.A.
#
#                                   Centro de trabajo   Año  Mes  \
# 0      Museo Regional de Historia de Aguascalientes  2019    1
# 1      Museo Regional de Historia de Aguascalientes  2019    1
# 2      Museo Regional de Historia de Aguascalientes  2019    1
# 3      Museo Regional de Historia de Aguascalientes  2019    1
# 4      Museo Regional de Historia de Aguascalientes  2019    1
# ...

# %%
del datos['Siglas']

# %%
datos
# Out:
#                Estado  Clave SIINAH  \
# 0      Aguascalientes     2300100.0
# 1      Aguascalientes     2300100.0
# 2      Aguascalientes     2300100.0
# 3      Aguascalientes     2300100.0
# 4      Aguascalientes     2300100.0
# ...               ...           ...
# 42674       Zacatecas     3110022.0
# 42675       Zacatecas     3110022.0
# 42676       Zacatecas     3110022.0
# 42677       Zacatecas     3110022.0
# 42678       Zacatecas     3110022.0
#
#                                   Centro de trabajo   Año  Mes  \
# 0      Museo Regional de Historia de Aguascalientes  2019    1
# 1      Museo Regional de Historia de Aguascalientes  2019    1
# 2      Museo Regional de Historia de Aguascalientes  2019    1
# 3      Museo Regional de Historia de Aguascalientes  2019    1
# 4      Museo Regional de Historia de Aguascalientes  2019    1
# ...                                             ...   ...  ...
# 42674         Z.A. de La Quemada con museo de sitio  2019   12
# ...

# %%
datos.Año.describe()
# Out:
# count    42679.0
# mean      2019.0
# std          0.0
# min       2019.0
# 25%       2019.0
# 50%       2019.0
# 75%       2019.0
# max       2019.0
# Name: Año, dtype: float64

# %%
datos.Mes.describe()
# Out:
# count    42679.000000
# mean         6.521779
# std          3.455479
# min          1.000000
# 25%          4.000000
# 50%          7.000000
# 75%         10.000000
# max         12.000000
# Name: Mes, dtype: float64

# %%
datos.Estado.describe()
# Out:
# count                42679
# unique                  32
# top       Estado de México
# freq                  4056
# Name: Estado, dtype: object

# %%
datos['Estado']
# Out:
# 0        Aguascalientes
# 1        Aguascalientes
# 2        Aguascalientes
# 3        Aguascalientes
# 4        Aguascalientes
#               ...
# 42674         Zacatecas
# 42675         Zacatecas
# 42676         Zacatecas
# 42677         Zacatecas
# 42678         Zacatecas
# Name: Estado, Length: 42679, dtype: object

# %%
datos['Estado', datos.Año.describe()]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-8e6364c482dd> in <module>
# ----> 1 datos['Estado', datos.Año.describe()]
#
# ~/anaconda3/envs/venv/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2897             if self.columns.nlevels > 1:
#    2898                 return self._getitem_multilevel(key)
# -> 2899             indexer = self.columns.get_loc(key)
#    2900             if is_integer(indexer):
#    2901                 indexer = [indexer]
#
# ~/anaconda3/envs/venv/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2887             casted_key = self._maybe_cast_indexer(key)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#    2891                 raise KeyError(key) from err
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/venv/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Aguascalientes'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-d81cbd08bb61> in <module>
# ...

# %%
datos['Estado'=='Aguascalientes']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/venv/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-ac3dd0f44570> in <module>
# ...

# %%
datos[datos['Estado']=='Aguascalientes']
# Out:
#              Estado  Clave SIINAH  \
# 0    Aguascalientes     2300100.0
# 1    Aguascalientes     2300100.0
# 2    Aguascalientes     2300100.0
# 3    Aguascalientes     2300100.0
# 4    Aguascalientes     2300100.0
# ..              ...           ...
# 151  Aguascalientes     2300100.0
# 152  Aguascalientes     2300100.0
# 153  Aguascalientes     2300100.0
# 154  Aguascalientes     2300100.0
# 155  Aguascalientes     2300100.0
#
#                                 Centro de trabajo   Año  Mes  \
# 0    Museo Regional de Historia de Aguascalientes  2019    1
# 1    Museo Regional de Historia de Aguascalientes  2019    1
# 2    Museo Regional de Historia de Aguascalientes  2019    1
# 3    Museo Regional de Historia de Aguascalientes  2019    1
# 4    Museo Regional de Historia de Aguascalientes  2019    1
# ..                                            ...   ...  ...
# 151  Museo Regional de Historia de Aguascalientes  2019   12
# ...

# %%
datos[datos['Estado']=='Aguascalientes'].describe()
# Out:
#        Clave SIINAH     Año        Mes
# count         156.0   156.0  156.00000
# mean      2300100.0  2019.0    6.50000
# std             0.0     0.0    3.46317
# min       2300100.0  2019.0    1.00000
# 25%       2300100.0  2019.0    3.75000
# 50%       2300100.0  2019.0    6.50000
# 75%       2300100.0  2019.0    9.25000
# max       2300100.0  2019.0   12.00000

# %%
datos.dropna['Clave SIINAH'].
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-f0cbc5183c2f> in <module>
# ----> 1 datos.dropna['Clave SIINAH'].datos[datos['Estado']=='Aguascalientes'].describe()
#
# TypeError: 'method' object is not subscriptable

# %%
datos[datos['Estado']=='Aguascalientes'].describe()
# Out:
#        Clave SIINAH     Año        Mes
# count         156.0   156.0  156.00000
# mean      2300100.0  2019.0    6.50000
# std             0.0     0.0    3.46317
# min       2300100.0  2019.0    1.00000
# 25%       2300100.0  2019.0    3.75000
# 50%       2300100.0  2019.0    6.50000
# 75%       2300100.0  2019.0    9.25000
# max       2300100.0  2019.0   12.00000

# %%
datos.drop(['Clave SIINAH'], axis=1 [datos['Estado']=='Aguascalientes'].describe())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-896cb0ad3389> in <module>
# ----> 1 datos.drop(['Clave SIINAH'], axis=1 [datos['Estado']=='Aguascalientes'].describe())
#
# TypeError: 'int' object is not subscriptable

# %%
datos[datos['Estado']=='Aguascalientes', 'Mes']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-92acecb5fead> in <module>
# ----> 1 datos[datos['Estado']=='Aguascalientes', 'Mes']
#       2
#
# ~/anaconda3/envs/venv/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2897             if self.columns.nlevels > 1:
#    2898                 return self._getitem_multilevel(key)
# -> 2899             indexer = self.columns.get_loc(key)
#    2900             if is_integer(indexer):
#    2901                 indexer = [indexer]
#
# ~/anaconda3/envs/venv/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2887             casted_key = self._maybe_cast_indexer(key)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
# ...

# %%
datos['Mes']
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 42674    12
# 42675    12
# 42676    12
# 42677    12
# 42678    12
# Name: Mes, Length: 42679, dtype: int64

# %%
# Out:
#              Estado  Clave SIINAH  \
# 0    Aguascalientes     2300100.0
# 1    Aguascalientes     2300100.0
# 2    Aguascalientes     2300100.0
# 3    Aguascalientes     2300100.0
# 4    Aguascalientes     2300100.0
# ..              ...           ...
# 151  Aguascalientes     2300100.0
# 152  Aguascalientes     2300100.0
# 153  Aguascalientes     2300100.0
# 154  Aguascalientes     2300100.0
# 155  Aguascalientes     2300100.0
#
#                                 Centro de trabajo   Año  Mes  \
# 0    Museo Regional de Historia de Aguascalientes  2019    1
# 1    Museo Regional de Historia de Aguascalientes  2019    1
# 2    Museo Regional de Historia de Aguascalientes  2019    1
# 3    Museo Regional de Historia de Aguascalientes  2019    1
# 4    Museo Regional de Historia de Aguascalientes  2019    1
# ..                                            ...   ...  ...
# 151  Museo Regional de Historia de Aguascalientes  2019   12
# ...

# %%
datos['Mes']
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 42674    12
# 42675    12
# 42676    12
# 42677    12
# 42678    12
# Name: Mes, Length: 42679, dtype: int64

# %%
datos['Estado']
# Out:
# 0        Aguascalientes
# 1        Aguascalientes
# 2        Aguascalientes
# 3        Aguascalientes
# 4        Aguascalientes
#               ...
# 42674         Zacatecas
# 42675         Zacatecas
# 42676         Zacatecas
# 42677         Zacatecas
# 42678         Zacatecas
# Name: Estado, Length: 42679, dtype: object

# %%
datos[datos['Estado']=='Aguascalientes']
# Out:
#              Estado  Clave SIINAH  \
# 0    Aguascalientes     2300100.0
# 1    Aguascalientes     2300100.0
# 2    Aguascalientes     2300100.0
# 3    Aguascalientes     2300100.0
# 4    Aguascalientes     2300100.0
# ..              ...           ...
# 151  Aguascalientes     2300100.0
# 152  Aguascalientes     2300100.0
# 153  Aguascalientes     2300100.0
# 154  Aguascalientes     2300100.0
# 155  Aguascalientes     2300100.0
#
#                                 Centro de trabajo   Año  Mes  \
# 0    Museo Regional de Historia de Aguascalientes  2019    1
# 1    Museo Regional de Historia de Aguascalientes  2019    1
# 2    Museo Regional de Historia de Aguascalientes  2019    1
# 3    Museo Regional de Historia de Aguascalientes  2019    1
# 4    Museo Regional de Historia de Aguascalientes  2019    1
# ..                                            ...   ...  ...
# 151  Museo Regional de Historia de Aguascalientes  2019   12
# ...

# %%
ag = datos[datos['Estado']=='Aguascalientes']

# %%
ag
# Out:
#              Estado                             Centro de trabajo   Año  Mes  \
# 0    Aguascalientes  Museo Regional de Historia de Aguascalientes  2019    1
# 1    Aguascalientes  Museo Regional de Historia de Aguascalientes  2019    1
# 2    Aguascalientes  Museo Regional de Historia de Aguascalientes  2019    1
# 3    Aguascalientes  Museo Regional de Historia de Aguascalientes  2019    1
# 4    Aguascalientes  Museo Regional de Historia de Aguascalientes  2019    1
# ..              ...                                           ...   ...  ...
# 151  Aguascalientes  Museo Regional de Historia de Aguascalientes  2019   12
# 152  Aguascalientes  Museo Regional de Historia de Aguascalientes  2019   12
# 153  Aguascalientes  Museo Regional de Historia de Aguascalientes  2019   12
# 154  Aguascalientes  Museo Regional de Historia de Aguascalientes  2019   12
# 155  Aguascalientes  Museo Regional de Historia de Aguascalientes  2019   12
#
# ...

# %%
ag['Mes']
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 151    12
# 152    12
# 153    12
# 154    12
# 155    12
# Name: Mes, Length: 156, dtype: int64

# %%
ag
# Out:
#              Estado                             Centro de trabajo   Año  Mes  \
# 0    Aguascalientes  Museo Regional de Historia de Aguascalientes  2019    1
# 1    Aguascalientes  Museo Regional de Historia de Aguascalientes  2019    1
# 2    Aguascalientes  Museo Regional de Historia de Aguascalientes  2019    1
# 3    Aguascalientes  Museo Regional de Historia de Aguascalientes  2019    1
# 4    Aguascalientes  Museo Regional de Historia de Aguascalientes  2019    1
# ..              ...                                           ...   ...  ...
# 151  Aguascalientes  Museo Regional de Historia de Aguascalientes  2019   12
# 152  Aguascalientes  Museo Regional de Historia de Aguascalientes  2019   12
# 153  Aguascalientes  Museo Regional de Historia de Aguascalientes  2019   12
# 154  Aguascalientes  Museo Regional de Historia de Aguascalientes  2019   12
# 155  Aguascalientes  Museo Regional de Historia de Aguascalientes  2019   12
#
# ...

# %%
ag['Número de visitas']
# Out:
# 0      527
# 1      617
# 2       19
# 3      188
# 4       80
#       ...
# 151      0
# 152      0
# 153     53
# 154      0
# 155      2
# Name: Número de visitas, Length: 156, dtype: object

# %%
datos['Número de visitas'].describe()
# Out:
# count     42679
# unique     3307
# top           0
# freq      20534
# Name: Número de visitas, dtype: object

# %%
ag['Número de visitas'].describe()
# Out:
# count     156
# unique     97
# top         0
# freq       37
# Name: Número de visitas, dtype: object

# %%
ag['Número de visitas']
# Out:
# 0      527
# 1      617
# 2       19
# 3      188
# 4       80
#       ...
# 151      0
# 152      0
# 153     53
# 154      0
# 155      2
# Name: Número de visitas, Length: 156, dtype: object

# %%
ag['Número de visitas'].describe()
# Out:
# count     156
# unique     97
# top         0
# freq       37
# Name: Número de visitas, dtype: object

# %%
ag['Número de visitas'].infer_objects()
# Out:
# 0      527
# 1      617
# 2       19
# 3      188
# 4       80
#       ...
# 151      0
# 152      0
# 153     53
# 154      0
# 155      2
# Name: Número de visitas, Length: 156, dtype: object

# %%
ag['Número de visitas'].to_numeric(s, downcast='integer')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-40c6d85558aa> in <module>
# ----> 1 ag['Número de visitas'].to_numeric(s, downcast='integer')
#
# ~/anaconda3/envs/venv/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5128             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5129                 return self[name]
# -> 5130             return object.__getattribute__(self, name)
#    5131
#    5132     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'to_numeric'

# %%
ag.to_numeric(s, downcast='integer')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-9dc030735b21> in <module>
# ----> 1 ag.to_numeric(s, downcast='integer')
#
# ~/anaconda3/envs/venv/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5128             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5129                 return self[name]
# -> 5130             return object.__getattribute__(self, name)
#    5131
#    5132     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'to_numeric'

# %%
ag.astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-7c7a2c4140de> in <module>
# ----> 1 ag.astype(int)
#
# ~/anaconda3/envs/venv/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5535         else:
#    5536             # else, only a single dtype is given
# -> 5537             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5538             return self._constructor(new_data).__finalize__(self, method="astype")
#    5539
#
# ~/anaconda3/envs/venv/lib/python3.7/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     565         self, dtype, copy: bool = False, errors: str = "raise"
#     566     ) -> "BlockManager":
# --> 567         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     568
#     569     def convert(
#
# ...

# %%
ag['Número de visitas'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-5859cf90c9ea> in <module>
# ----> 1 ag['Número de visitas'].astype(int)
#
# ~/anaconda3/envs/venv/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5535         else:
#    5536             # else, only a single dtype is given
# -> 5537             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5538             return self._constructor(new_data).__finalize__(self, method="astype")
#    5539
#
# ~/anaconda3/envs/venv/lib/python3.7/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     565         self, dtype, copy: bool = False, errors: str = "raise"
#     566     ) -> "BlockManager":
# --> 567         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     568
#     569     def convert(
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-8ea7077a8749> in <module>
# ----> 1 ag['Número de visitas'].astype(float)
#
# ~/anaconda3/envs/venv/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5535         else:
#    5536             # else, only a single dtype is given
# -> 5537             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5538             return self._constructor(new_data).__finalize__(self, method="astype")
#    5539
#
# ~/anaconda3/envs/venv/lib/python3.7/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     565         self, dtype, copy: bool = False, errors: str = "raise"
#     566     ) -> "BlockManager":
# --> 567         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     568
#     569     def convert(
#
# ...
